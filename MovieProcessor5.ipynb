# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("main_data.csv")

# %%
dataset
# Out:
#           director_name  ...                                               comb
# 0         James Cameron  ...  CCH Pounder Joel David Moore Wes Studi James C...
# 1        Gore Verbinski  ...  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2            Sam Mendes  ...  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Christopher Nolan  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4           Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                 ...  ...                                                ...
# 6495     Garth Jennings  ...  Matthew McConaughey Reese Witherspoon Scarlett...
# 6496     Matthew Vaughn  ...  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 6497          Joel Coen  ...  Denzel Washington Frances McDormand Corey Hawk...
# 6498     Erwin brothers  ...  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 6499         Joe Wright  ...  Peter Dinklage Haley Bennett Kelvin Harrison J...
#
# ...

# %%
dataset1 = dataset.iloc[:4917,:]
dataset2 = dataset.iloc[4917:,:]

# %%
dataset1["movie_title"][0]
# Out:
# 'avatar\xa0'

# %%
dataset1['movie_title'] = dataset1['movie_title'].apply(lambda x : x[:-1])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset1["movie_title"][0]
# Out:
# 'avatar'

# %%
editedmain_data = dataset1.append(dataset2)

# %%
editedmain_data.shape
# Out:
# (6500, 7)

# %%
editedmain_data.tail()
# Out:
#        director_name  ...                                               comb
# 6495  Garth Jennings  ...  Matthew McConaughey Reese Witherspoon Scarlett...
# 6496  Matthew Vaughn  ...  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 6497       Joel Coen  ...  Denzel Washington Frances McDormand Corey Hawk...
# 6498  Erwin brothers  ...  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 6499      Joe Wright  ...  Peter Dinklage Haley Bennett Kelvin Harrison J...
#
# [5 rows x 7 columns]

# %%
editedmain_data.to_csv("editedmain_data.csv", index=False)
